# %% [markdown]
# <a href="https://colab.research.google.com/github/Lee-Kiwon/SKT_FLY_AI/blob/main/%EB%A9%B4%EC%A0%91%EB%82%A8%EB%85%80%EA%B5%AC%EB%B6%84.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 압축 해제할 폴더 경로
zip_file_path = '/content/TL_01.Management_Male_Experienced.zip'

# 압축 해제할 폴더 경로
extract_folder_path = 'TL_01.Management_Male_Experienced'

# 압축 해제
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_folder_path)

# %%
import os
import json
import pandas as pd

# 각 폴더의 경로
folder_paths = ['TL_01.Management_Male_Experienced', 'TL_01.Management_Female_Experienced']

# 데이터를 저장할 리스트
data = []

# 폴더마다 JSON 파일 읽어서 데이터에 추가
for folder_path in folder_paths:
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and file_name.endswith('.json'):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    json_data = json.load(file)
                    text = json_data.get('dataSet', {}).get('answer', {}).get('raw', {}).get('text', '')  # 'text' 항목 추출
                    place = json_data.get('dataSet', {}).get('info', {}).get('place', '')  # 'place' 항목 추출
                    # 'place'가 'ONLINE'이면 0, 'OFFLINE'이면 1로 라벨링
                    label = 0 if place == 'ONLINE' else 1
                    data.append((text, label))
            except Exception as e:
                print(f"Error processing file: {file_path}. Skipping this file. Error: {e}")

# 데이터프레임 생성
df = pd.DataFrame(data, columns=['text', 'label'])

# CSV 파일로 저장
csv_file_path = 'combined_data.csv'
df.to_csv(csv_file_path, index=False)

print("CSV 파일이 생성되었습니다.")
# Out:
# CSV 파일이 생성되었습니다.

# %%
import os
import json
import pandas as pd

# 각 폴더의 경로
folder_paths = ['TL_01.Management_Male_Experienced', 'TL_01.Management_Female_Experienced']

# 데이터를 저장할 리스트
data = []

# 폴더마다 JSON 파일 읽어서 데이터에 추가
for folder_path in folder_paths:
    for file_name in os.listdir(folder_path):
        file_path = os.path.join(folder_path, file_name)
        if os.path.isfile(file_path) and file_name.endswith('.json'):
            try:
                with open(file_path, 'r', encoding='utf-8') as file:
                    json_data = json.load(file)
                    text = json_data.get('dataSet', {}).get('answer', {}).get('raw', {}).get('text', '')  # 'text' 항목 추출
                    gender = json_data.get('dataSet', {}).get('info', {}).get('gender', '')  # 'gender' 항목 추출
                    # 'gender'가 'MALE'이면 0, 'FEMALE'이면 1로 라벨링
                    label = 0 if gender == 'MALE' else 1
                    data.append((text, label))
            except Exception as e:
                print(f"Error processing file: {file_path}. Skipping this file. Error: {e}")

# 데이터프레임 생성
df = pd.DataFrame(data, columns=['text', 'label'])

# CSV 파일로 저장
csv_file_path = 'combined_data.csv'
df.to_csv(csv_file_path, index=False)

print("CSV 파일이 생성되었습니다.")
# Out:
# Error processing file: TL_01.Management_Male_Experienced/ckmk_d_bm_m_e_229448.json. Skipping this file. Error: name 'place' is not defined
# Error processing file: TL_01.Management_Male_Experienced/ckmk_d_bm_m_e_246647.json. Skipping this file. Error: name 'place' is not defined
# Error processing file: TL_01.Management_Male_Experienced/ckmk_d_bm_m_e_137536.json. Skipping this file. Error: name 'place' is not defined
# Error processing file: TL_01.Management_Male_Experienced/ckmk_d_bm_m_e_261642.json. Skipping this file. Error: name 'place' is not defined
# Error processing file: TL_01.Management_Male_Experienced/ckmk_d_bm_m_e_100021.json. Skipping this file. Error: name 'place' is not defined
# Error processing file: TL_01.Management_Male_Experienced/ckmk_d_bm_m_e_287516.json. Skipping this file. Error: name 'place' is not defined
# Error processing file: TL_01.Management_Male_Experienced/ckmk_d_bm_m_e_285634.json. Skipping this file. Error: name 'place' is not defined
# ...

# %%
# import os
# import zipfile
# import pandas as pd
# import nltk
# nltk.download('punkt')
# from nltk.tokenize import sent_tokenize

# # 압축 해제할 폴더 경로
# zip_file_path = 'VS_뉴스_IT과학.zip'

# # 압축 해제할 폴더 경로
# extract_folder_path = 'VS_뉴스_IT과학'

# # 압축 해제
# with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
#     zip_ref.extractall(extract_folder_path)

# # 텍스트 파일 읽어서 DataFrame에 저장
# data = []

# # 뉴스 폴더
# news_folder = 'VS_뉴스_IT과학'

# # 라벨링
# for file_name in os.listdir(news_folder):
#     file_path = os.path.join(news_folder, file_name)
#     if os.path.isfile(file_path):
#         with open(file_path, 'r', encoding='utf-8') as file:
#             content = file.read()
#             sentences = sent_tokenize(content)  # 문장 분할
#             for sentence in sentences:
#                 data.append((sentence, 0))  # 뉴스 폴더는 0으로 라벨링

# # 다른 폴더
# other_folder = 'VS_뉴스_금융'

# # 라벨링
# for file_name in os.listdir(other_folder):
#     file_path = os.path.join(other_folder, file_name)
#     if os.path.isfile(file_path):
#         with open(file_path, 'r', encoding='utf-8') as file:
#             content = file.read()
#             sentences = sent_tokenize(content)  # 문장 분할
#             for sentence in sentences:
#                 data.append((sentence, 1))  # 다른 폴더는 1으로 라벨링

# # DataFrame으로 변환
# df = pd.DataFrame(data, columns=['content', 'label'])

# # CSV 파일로 저장
# csv_file_path = 'news_data.csv'
# df.to_csv(csv_file_path, index=False)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
# 필요한 모듈 임포트
import pandas as pd
import tensorflow as tf
from tensorflow.keras import preprocessing
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, Dense, Dropout, Conv1D, GlobalMaxPool1D, concatenate

# 데이터 읽어오기
train_file = "/content/combined_data.csv"
data = pd.read_csv(train_file, delimiter=',')
features = data['text'].tolist()
labels = data['label'].tolist()

# %%
# 단어 인덱스 시퀀스 벡터
corpus = [preprocessing.text.text_to_word_sequence(text) for text in features]

tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)
word_index = tokenizer.word_index
MAX_SEQ_LEN = 15  # 단어 시퀀스 벡터 크기
padded_seqs = preprocessing.sequence.pad_sequences(sequences, maxlen=MAX_SEQ_LEN, padding='post')

# 학습용, 검증용, 테스트용 데이터셋 생성 ➌
# 학습셋:검증셋:테스트셋 = 7:2:1
ds = tf.data.Dataset.from_tensor_slices((padded_seqs, labels))
ds = ds.shuffle(len(features))
train_size = int(len(padded_seqs) * 0.7)
val_size = int(len(padded_seqs) * 0.2)
test_size = int(len(padded_seqs) * 0.1)
train_ds = ds.take(train_size).batch(20)
val_ds = ds.skip(train_size).take(val_size).batch(20)
test_ds = ds.skip(train_size + val_size).take(test_size).batch(20)

# 하이퍼파라미터 설정
dropout_prob = 0.5
EMB_SIZE = 128
EPOCH = 5
VOCAB_SIZE = len(word_index) + 1  # 전체 단어 수

# CNN 모델 정의
input_layer = Input(shape=(MAX_SEQ_LEN,))
embedding_layer = Embedding(VOCAB_SIZE, EMB_SIZE, input_length=MAX_SEQ_LEN)(input_layer)
dropout_emb = Dropout(rate=dropout_prob)(embedding_layer)

conv1 = Conv1D(filters=128, kernel_size=3, padding='valid', activation=tf.nn.relu)(dropout_emb)
pool1 = GlobalMaxPool1D()(conv1)
conv2 = Conv1D(filters=128, kernel_size=4, padding='valid', activation=tf.nn.relu)(dropout_emb)
pool2 = GlobalMaxPool1D()(conv2)
conv3 = Conv1D(filters=128, kernel_size=5, padding='valid', activation=tf.nn.relu)(dropout_emb)
pool3 = GlobalMaxPool1D()(conv3)

# 3, 4, 5- gram 이후 합치기
concat = concatenate([pool1, pool2, pool3])
hidden = Dense(128, activation=tf.nn.relu)(concat)
dropout_hidden = Dropout(rate=dropout_prob)(hidden)
logits = Dense(3, name='logits')(dropout_hidden)
predictions = Dense(3, activation=tf.nn.softmax)(logits)

# 모델 생성
model = Model(inputs=input_layer, outputs=predictions)
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# 모델 학습
model.fit(train_ds, validation_data=val_ds, epochs=EPOCH, verbose=1)

# 모델 평가(테스트 데이터셋 이용)
loss, accuracy = model.evaluate(test_ds, verbose=1)
print('Accuracy: %f' % (accuracy * 100))
print('loss: %f' % (loss))

# 모델 저장
model.save('cnn_model.h5')
# Out:
# Epoch 1/5
# 84/84 [==============================] - 10s 105ms/step - loss: 0.1158 - accuracy: 0.9934 - val_loss: 0.0023 - val_accuracy: 1.0000
# Epoch 2/5
# 84/84 [==============================] - 12s 137ms/step - loss: 5.8106e-04 - accuracy: 1.0000 - val_loss: 7.3416e-04 - val_accuracy: 1.0000
# Epoch 3/5
# 84/84 [==============================] - 9s 103ms/step - loss: 2.2468e-04 - accuracy: 1.0000 - val_loss: 2.5267e-04 - val_accuracy: 1.0000
# Epoch 4/5
# 84/84 [==============================] - 7s 86ms/step - loss: 1.0100e-04 - accuracy: 1.0000 - val_loss: 7.6565e-05 - val_accuracy: 1.0000
# Epoch 5/5
# ...
# 12/12 [==============================] - 0s 4ms/step - loss: 3.9524e-05 - accuracy: 1.0000
# Accuracy: 100.000000
# loss: 0.000040
# ...

# %%
import tensorflow as tf
import pandas as pd
from tensorflow.keras.models import Model, load_model
from tensorflow.keras import preprocessing

# 데이터 읽어오기
train_file = "/content/combined_data.csv"
data = pd.read_csv(train_file, delimiter=',')
features = data['text'].tolist()
labels = data['label'].tolist()

# 단어 인덱스 시퀀스 벡터
corpus = [preprocessing.text.text_to_word_sequence(text) for text in features]
tokenizer = preprocessing.text.Tokenizer()
tokenizer.fit_on_texts(corpus)
sequences = tokenizer.texts_to_sequences(corpus)
MAX_SEQ_LEN = 15 # 단어 시퀀스 벡터 크기
padded_seqs = preprocessing.sequence.pad_sequences(sequences, maxlen=MAX_SEQ_LEN, padding='post')

# 테스트용 데이터셋 생성
ds = tf.data.Dataset.from_tensor_slices((padded_seqs, labels))
ds = ds.shuffle(len(features))
test_ds = ds.take(2000).batch(20) # 테스트 데이터셋

# 감정 분류 CNN 모델 불러오기
model = load_model('cnn_model.h5')
model.summary()
model.evaluate(test_ds, verbose=2)

# 테스트용 데이터셋의 5번째 데이터 출력
print("단어 시퀀스 : ", corpus[3])
print("단어 인덱스 시퀀스 : ", padded_seqs[3])
print("문장 분류(정답) : ", labels[3])

# 테스트용 데이터셋의 5 데이터 감정 예측
picks = [3]
predict = model.predict(padded_seqs[picks])
predict_class = tf.math.argmax(predict, axis=1)
print("면접 장소 예측 점수 : ", predict)
print("면접 장소 예측 클래스 : ", predict_class.numpy())
# Out:
# Model: "model_4"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_5 (InputLayer)        [(None, 15)]                 0         []
#
#  embedding_4 (Embedding)     (None, 15, 128)              4911104   ['input_5[0][0]']
#
#  dropout_8 (Dropout)         (None, 15, 128)              0         ['embedding_4[0][0]']
#
#  conv1d_12 (Conv1D)          (None, 13, 128)              49280     ['dropout_8[0][0]']
#
#  conv1d_13 (Conv1D)          (None, 12, 128)              65664     ['dropout_8[0][0]']
#
#  conv1d_14 (Conv1D)          (None, 11, 128)              82048     ['dropout_8[0][0]']
#
#  global_max_pooling1d_12 (G  (None, 128)                  0         ['conv1d_12[0][0]']
#  lobalMaxPooling1D)
#
#  global_max_pooling1d_13 (G  (None, 128)                  0         ['conv1d_13[0][0]']
#  lobalMaxPooling1D)
#
# ...
